# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('house_price_data_200.xlsx')

# %%
df.head()
# Out:
#    Serial Number           Name       State  Floor Interior Design  BHK  \
# 0              1   Diana Murphy       Texas      2         Premium    3
# 1              2  Alice Johnson       Texas      2           Basic    3
# 2              3       John Doe     Florida      1          Luxury    1
# 3              4    Umar Nelson       Texas      1           Basic    1
# 4              5   Julia Howard  California      4           Basic    5
#
#     Price
# 0  240000
# 1  200000
# 2  160000
# 3   90000
# 4  320000

# %%
plt.scatter(df['BHK'], df['Price'])
plt.xlabel('BHK')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
X=df.iloc[:,5:7]

# %%
X.head()
# Out:
#    BHK   Price
# 0    3  240000
# 1    3  200000
# 2    1  160000
# 3    1   90000
# 4    5  320000

# %%
Y=df.iloc[:,-1]

# %%
Y.head()
# Out:
# 0    240000
# 1    200000
# 2    160000
# 3     90000
# 4    320000
# Name: Price, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1,random_state = 0)

# %%
X_train.head()
# Out:
#      BHK   Price
# 183    4  270000
# 145    3  270000
# 45     5  350000
# 159    5  330000
# 60     3  190000

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train= scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.66738853,  0.32409385],
#        [-0.06960494,  0.32409385],
#        [ 1.404382  ,  1.42220008],
#        [ 1.404382  ,  1.14767352],
#        [-0.06960494, -0.77401238],
#        [ 1.404382  ,  1.97125319],
#        [ 1.404382  ,  1.14767352],
#        [ 0.66738853,  0.46135713],
#        [-1.54359188, -1.04853893],
#        [-1.54359188, -1.04853893],
#        [-0.06960494, -0.22495926],
#        [-0.06960494,  0.32409385],
#        [ 1.404382  ,  0.59862041],
#        [-0.80659841, -0.49948582],
#        [-0.06960494,  0.32409385],
#        [ 0.66738853,  0.46135713],
#        [ 0.66738853,  0.18683057],
#        [ 1.404382  ,  1.01041024],
#        [-1.54359188, -0.77401238],
#        [ 0.66738853,  0.04956729],
#        [-0.80659841, -0.77401238],
#        [ 0.66738853,  0.32409385],
#        [-0.06960494, -0.49948582],
#        [ 1.404382  ,  1.55946336],
#        [-0.06960494, -0.49948582],
#        [ 1.404382  ,  1.42220008],
#        [-0.80659841, -0.77401238],
#        [ 0.66738853,  0.59862041],
#        [-1.54359188, -1.59759205],
#        [-1.54359188, -0.6367491 ],
#        [-1.54359188, -1.59759205],
#        [-0.80659841,  0.04956729],
#        [-0.80659841, -1.04853893],
#        [-0.06960494, -0.49948582],
#        [ 0.66738853,  0.46135713],
#        [-1.54359188, -1.8721186 ],
#        [ 0.66738853,  1.01041024],
#        [ 0.66738853,  0.59862041],
#        [-0.80659841, -1.04853893],
#        [-0.06960494, -0.22495926],
#        [ 0.66738853,  0.73588369],
#        [-0.80659841, -0.22495926],
#        [-0.80659841, -1.18580221],
#        [ 1.404382  ,  1.69672664],
#        [-0.06960494,  0.18683057],
#        [-0.06960494, -0.77401238],
#        [ 0.66738853,  1.2849368 ],
#        [ 0.66738853,  0.73588369],
#        [ 0.66738853,  0.87314697],
#        [-0.06960494,  0.32409385],
#        [-0.06960494,  0.04956729],
#        [-0.06960494,  0.59862041],
#        [-0.80659841, -0.91127565],
#        [-0.06960494,  0.59862041],
#        [ 0.66738853,  0.46135713],
#        [-0.80659841, -0.6367491 ],
#        [ 1.404382  ,  0.73588369],
#        [ 1.404382  ,  0.59862041],
#        [ 0.66738853,  0.87314697],
#        [ 0.66738853,  1.01041024],
#        [-0.06960494, -0.22495926],
#        [ 0.66738853,  0.32409385],
#        [-0.06960494, -0.49948582],
#        [-0.80659841, -1.46032877],
#        [-1.54359188, -1.73485532],
#        [ 1.404382  ,  0.73588369],
#        [-1.54359188, -1.18580221],
#        [ 1.404382  ,  1.69672664],
#        [-1.54359188, -1.73485532],
#        [ 0.66738853, -0.08769598],
#        [-0.06960494,  0.32409385],
#        [ 0.66738853,  1.2849368 ],
#        [-0.06960494, -0.22495926],
#        [-1.54359188, -1.32306549],
#        [-0.80659841, -0.49948582],
#        [ 0.66738853,  0.18683057],
#        [ 0.66738853,  0.73588369],
#        [-1.54359188, -1.59759205],
#        [-0.80659841, -0.91127565],
#        [-0.06960494,  0.18683057],
#        [ 1.404382  ,  1.01041024],
#        [-0.80659841, -0.49948582],
#        [-0.80659841, -0.36222254],
#        [-0.06960494, -0.08769598],
#        [ 1.404382  ,  1.55946336],
#        [-0.80659841, -0.77401238],
#        [ 0.66738853,  0.46135713],
#        [-0.80659841,  0.04956729],
#        [-1.54359188, -1.73485532],
#        [ 1.404382  ,  1.42220008],
#        [-0.80659841, -0.22495926],
#        [ 1.404382  ,  1.14767352],
#        [-1.54359188, -1.04853893],
#        [-1.54359188, -1.8721186 ],
#        [ 1.404382  ,  1.01041024],
#        [-0.06960494,  0.32409385],
#        [-1.54359188, -1.46032877],
#        [-0.06960494, -0.49948582],
#        [-0.06960494, -0.49948582],
#        [-0.06960494,  0.46135713],
#        [-0.06960494,  0.18683057],
#        [-0.80659841, -1.18580221],
#        [ 1.404382  ,  0.73588369],
#        [-0.06960494,  0.59862041],
#        [ 1.404382  ,  1.69672664],
#        [-0.80659841, -0.6367491 ],
#        [-1.54359188, -2.14664516],
#        [-0.80659841, -1.18580221],
#        [ 0.66738853,  0.87314697],
#        [-1.54359188, -1.59759205],
#        [-1.54359188, -0.91127565],
#        [ 0.66738853,  0.87314697],
#        [-1.54359188, -1.04853893],
#        [ 1.404382  ,  0.87314697],
#        [ 1.404382  ,  1.97125319],
#        [-0.06960494, -0.77401238],
#        [-1.54359188, -1.59759205],
#        [-1.54359188, -1.59759205],
#        [ 0.66738853,  0.18683057],
#        [ 1.404382  ,  1.83398991],
#        [ 0.66738853,  0.87314697],
#        [ 1.404382  ,  1.97125319],
#        [ 0.66738853,  0.59862041],
#        [ 0.66738853,  0.46135713],
#        [-0.06960494,  0.73588369],
#        [-0.06960494, -0.6367491 ],
#        [-0.80659841, -1.32306549],
#        [-0.80659841, -0.91127565],
#        [-0.80659841, -0.91127565],
#        [ 0.66738853,  0.46135713],
#        [ 0.66738853,  0.18683057],
#        [ 0.66738853,  0.87314697],
#        [ 0.66738853,  0.73588369],
#        [ 0.66738853,  0.73588369],
#        [ 1.404382  ,  1.83398991],
#        [-1.54359188, -1.8721186 ],
#        [-0.06960494, -0.08769598],
#        [-0.06960494,  0.04956729],
#        [ 1.404382  ,  0.73588369],
#        [ 0.66738853,  0.73588369],
#        [ 1.404382  ,  0.59862041],
#        [-0.80659841, -0.22495926],
#        [ 0.66738853,  0.46135713],
#        [-0.06960494, -0.22495926],
#        [ 0.66738853,  0.46135713],
#        [ 1.404382  ,  1.55946336],
#        [-0.06960494,  0.04956729],
#        [-0.06960494, -0.36222254],
#        [-0.06960494, -0.22495926],
#        [-0.06960494, -0.22495926],
#        [-0.06960494, -0.22495926],
#        [-1.54359188, -1.59759205],
#        [-0.80659841, -0.22495926],
#        [ 1.404382  ,  1.01041024],
#        [-0.06960494,  0.32409385],
#        [ 1.404382  ,  1.97125319],
#        [ 0.66738853,  0.04956729],
#        [-1.54359188, -1.59759205],
#        [-0.06960494,  0.59862041],
#        [-1.54359188, -0.6367491 ],
#        [-0.80659841, -0.49948582],
#        [-1.54359188, -1.04853893],
#        [-1.54359188, -2.00938188],
#        [-0.06960494,  0.32409385],
#        [-1.54359188, -1.32306549],
#        [ 1.404382  ,  1.14767352],
#        [ 1.404382  ,  1.01041024],
#        [-0.06960494, -0.08769598],
#        [-0.06960494,  0.59862041],
#        [-1.54359188, -1.8721186 ],
#        [-0.80659841, -1.04853893],
#        [-0.06960494, -0.22495926],
#        [-1.54359188, -1.59759205],
#        [ 1.404382  ,  1.42220008],
#        [-0.06960494, -0.22495926],
#        [ 1.404382  ,  1.69672664],
#        [-0.80659841, -1.46032877],
#        [ 1.404382  ,  1.14767352],
#        [ 0.66738853,  0.59862041],
#        [-0.80659841, -0.22495926]])

# %%
X_test= scaler.fit_transform(X_test)

# %%
X_test
# Out:
# array([[-0.36760731, -0.46577334],
#        [-0.36760731, -0.32245846],
#        [ 1.83803656,  2.40052412],
#        [ 1.83803656,  1.39732001],
#        [ 1.10282193,  1.11069026],
#        [-1.10282193, -0.32245846],
#        [ 1.10282193,  0.53743077],
#        [-1.10282193, -0.89571795],
#        [-1.10282193, -1.1823477 ],
#        [-0.36760731, -0.60908821],
#        [-1.10282193, -1.03903283],
#        [ 1.10282193,  0.82406052],
#        [-1.10282193, -1.46897745],
#        [-1.10282193, -0.75240308],
#        [ 0.36760731,  0.68074565],
#        [ 1.10282193,  1.11069026],
#        [-0.36760731, -0.89571795],
#        [-0.36760731, -0.75240308],
#        [-0.36760731,  0.25080103],
#        [ 0.36760731,  0.3941159 ]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
Y_pred = clf.predict(X_test)

# %%
Y_pred
# Out:
# array([230000, 230000, 390000, 320000, 300000, 230000, 300000, 170000,
#        130000, 230000, 170000, 300000, 130000, 230000, 290000, 300000,
#        210000, 230000, 230000, 290000])

# %%
Y_test
# Out:
# 18     190000
# 170    200000
# 107    390000
# 98     320000
# 177    300000
# 182    200000
# 5      260000
# 146    160000
# 12     140000
# 152    180000
# 61     150000
# 125    280000
# 180    120000
# 154    170000
# 80     270000
# 7      300000
# 33     160000
# 130    170000
# 37     240000
# 74     250000
# Name: Price, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test,Y_pred)
# Out:
# 0.2
